# %%
import re
import requests
import pymysql
from bs4 import BeautifulSoup

# %%
# MySQL 접속 설정 (실제 정보로 변경)
MYSQL_HOST = ''
MYSQL_PORT = 3306
MYSQL_USER = ''
MYSQL_PASSWORD = ''
MYSQL_DB = ''

# %%
def parse_supply_target(soup, subscription_info_id, house_manage_no):
    """
    '공급대상' 테이블 파싱
    """
    targets = []
    # h5 태그에서 "공급대상" 텍스트를 찾아 그 다음 테이블을 선택
    supply_target_h5 = soup.find("h5", string=lambda x: x and "공급대상" in x)
    if not supply_target_h5:
        return targets
        
    table = supply_target_h5.find_next("table")
    if not table:
        return targets
        
    tbody = table.find("tbody")
    if not tbody:
        return targets
        
    rows = tbody.find_all("tr")
    current_housing_category = None
    
    for row in rows:
        cells = row.find_all("td")
        
        # 합계 행 건너뛰기
        if cells and "계" in cells[0].get_text(strip=True):
            continue
            
        if len(cells) >= 6:  # 데이터 행
            if len(cells) == 7:  # housing_category 포함된 행
                current_housing_category = cells[0].get_text(strip=True)
                start_idx = 1
            else:  # housing_category 없는 행
                start_idx = 0
                
            housing_type = cells[start_idx].get_text(strip=True)
            supply_area = cells[start_idx + 1].get_text(strip=True)
            supply_count_normal = cells[start_idx + 2].get_text(strip=True)
            supply_count_special = cells[start_idx + 3].get_text(strip=True)
            supply_count_total = cells[start_idx + 4].get_text(strip=True)
            house_manage_no_detail = cells[start_idx + 5].get_text(strip=True)
            
            try:
                supply_area_val = float(supply_area.replace(',', '')) if supply_area else None
            except:
                supply_area_val = None
            try:
                supply_count_normal_val = int(supply_count_normal.replace(',', '')) if supply_count_normal else None
            except:
                supply_count_normal_val = None
            try:
                supply_count_special_val = int(supply_count_special.replace(',', '')) if supply_count_special else None
            except:
                supply_count_special_val = None
            try:
                supply_count_total_val = int(supply_count_total.replace(',', '')) if supply_count_total else None
            except:
                supply_count_total_val = None

            targets.append({
                'subscription_info_id': subscription_info_id,
                'house_manage_no': house_manage_no,
                'housing_category': current_housing_category,
                'housing_type': housing_type,
                'supply_area': supply_area_val,
                'supply_count_normal': supply_count_normal_val,
                'supply_count_special': supply_count_special_val,
                'supply_count_total': supply_count_total_val,
                'house_manage_no_detail': house_manage_no_detail
            })
    
    return targets

def parse_special_supply_target(soup, subscription_info_id, house_manage_no):
    """
    '특별공급 공급대상' 테이블 파싱
    """
    special_targets = []
    # h5 태그에서 "특별공급 공급대상" 텍스트를 찾아 그 다음 테이블을 선택
    special_target_h5 = soup.find("h5", string=lambda x: x and "특별공급 공급대상" in x)
    if not special_target_h5:
        return special_targets
        
    table = special_target_h5.find_next("table")
    if not table:
        return special_targets
        
    tbody = table.find("tbody")
    if not tbody:
        return special_targets
        
    rows = tbody.find_all("tr")
    for row in rows:
        cells = row.find_all("td")
        if len(cells) != 11:  # 주택형 + 9개 공급유형 + 계
            continue
            
        housing_type = cells[0].get_text(strip=True)
        
        # 각 공급유형별 세대수 파싱
        supply_counts = {}
        supply_types = ['multichild', 'newlywed', 'first', 'youth', 'elderly', 
                       'newborn', 'institution_recommend', 'previous_institution', 'others', 'total']
                       
        for i, supply_type in enumerate(supply_types, 1):
            try:
                count = int(cells[i].get_text(strip=True).replace(',', ''))
            except:
                count = None
            supply_counts[f'supply_count_{supply_type}'] = count

        special_targets.append({
            'subscription_info_id': subscription_info_id,
            'house_manage_no': house_manage_no,
            'housing_type': housing_type,
            **supply_counts
        })
    
    return special_targets

def parse_price_info(soup, subscription_info_id, house_manage_no):
    """
    '공급금액' 테이블 파싱
    """
    price_infos = []
    # h5 태그에서 "공급금액" 텍스트를 찾아 그 다음 테이블을 선택
    price_h5 = soup.find("h5", string=lambda x: x and "공급금액" in x)
    if not price_h5:
        return price_infos
        
    table = price_h5.find_next("table")
    if not table:
        return price_infos
        
    tbody = table.find("tbody")
    if not tbody:
        return price_infos
        
    # 2순위 청약금 정보 찾기
    second_priority_cell = tbody.find("td", string=lambda x: x and "청약통장" in str(x))
    second_priority_payment = second_priority_cell.get_text(strip=True) if second_priority_cell else None
    
    rows = tbody.find_all("tr")
    for row in rows:
        cells = row.find_all("td")
        if len(cells) >= 2:
            housing_type = cells[0].get_text(strip=True)
            supply_price_text = cells[1].get_text(strip=True).replace(',', '')
            try:
                supply_price = int(supply_price_text)
            except:
                supply_price = None

            # 입주예정월 찾기
            move_in_month = None
            move_in_li = soup.find("li", string=lambda x: x and "입주예정월" in str(x))
            if move_in_li:
                text = move_in_li.get_text(strip=True)
                import re
                m = re.search(r"입주예정월\s*[:：]\s*([\d\.]+)", text)
                if m:
                    move_in_month = m.group(1)

            price_infos.append({
                'subscription_info_id': subscription_info_id,
                'house_manage_no': house_manage_no,
                'housing_type': housing_type,
                'supply_price': supply_price,
                'second_priority_payment': second_priority_payment,
                'move_in_month': move_in_month
            })
    
    return price_infos

# %%
def insert_data(conn, table, data):
    """
    conn: pymysql connection  
    table: 삽입할 테이블 이름 (문자열)  
    data: 딕셔너리의 리스트
    """
    if not data:
        return
    keys = data[0].keys()
    columns = ", ".join(keys)
    placeholders = ", ".join(["%s"] * len(keys))
    query = f"INSERT INTO {table} ({columns}) VALUES ({placeholders})"
    with conn.cursor() as cursor:
        for row in data:
            values = tuple(row[k] for k in keys)
            cursor.execute(query, values)
    conn.commit()

def main():
    # MySQL RDS 연결
    conn = pymysql.connect(
        host=MYSQL_HOST,
        port=MYSQL_PORT,
        user=MYSQL_USER,
        password=MYSQL_PASSWORD,
        database=MYSQL_DB,
        charset='utf8mb4'
    )
    try:
        with conn.cursor() as cursor:
            # subscription_info 테이블에서 id, pblanc_url, house_manage_no 조회
            sql = "SELECT id, pblanc_url, house_manage_no FROM subscription_info"
            cursor.execute(sql)
            rows = cursor.fetchall()
            
            for row in rows:
                subscription_info_id = row[0]
                pblanc_url = row[1]
                house_manage_no = row[2]
                if not pblanc_url:
                    print(f"ID {subscription_info_id}: pblanc_url이 없습니다.")
                    continue
                
                try:
                    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36"}
                    response = requests.get(pblanc_url, headers=headers, timeout=10)

                    if response.status_code == 200:
                        html = response.text
                        soup = BeautifulSoup(html, 'html.parser')
                        
                        # 공급대상 정보 파싱 및 삽입
                        supply_targets = parse_supply_target(soup, subscription_info_id, house_manage_no)
                        if supply_targets:
                            insert_data(conn, "subscription_supply_target", supply_targets)
                            print(f"ID {subscription_info_id} 공급대상 정보 삽입 완료: {len(supply_targets)} 건")
                        else:
                            print(f"ID {subscription_info_id} 공급대상 정보 없음")
                        
                        # 특별공급 공급대상 정보 파싱 및 삽입
                        special_supply_targets = parse_special_supply_target(soup, subscription_info_id, house_manage_no)
                        if special_supply_targets:
                            insert_data(conn, "subscription_special_supply_target", special_supply_targets)
                            print(f"ID {subscription_info_id} 특별공급 공급대상 정보 삽입 완료: {len(special_supply_targets)} 건")
                        else:
                            print(f"ID {subscription_info_id} 특별공급 공급대상 정보 없음")
                        
                        # 공급금액 및 입주예정월 정보 파싱 및 삽입
                        price_infos = parse_price_info(soup, subscription_info_id, house_manage_no)
                        if price_infos:
                            insert_data(conn, "subscription_price_info", price_infos)
                            print(f"ID {subscription_info_id} 공급금액 정보 삽입 완료: {len(price_infos)} 건")
                        else:
                            print(f"ID {subscription_info_id} 공급금액 정보 없음")
                    else:
                        print(f"ID {subscription_info_id}: URL 요청 실패, status code {response.status_code}")
                except Exception as e:
                    print(f"ID {subscription_info_id} 처리 중 오류 발생: {e}")
                
    finally:
        conn.close()

if __name__ == "__main__":
    main()
# Out:
# ID 1 공급대상 정보 삽입 완료: 6 건
# ID 1 특별공급 공급대상 정보 삽입 완료: 6 건
# ID 1 공급금액 정보 삽입 완료: 6 건
# <Response [200]>
#
# <!DOCTYPE html>
#
# <html lang="ko" style="overflow: hidden;height:97%">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, user-scalable=yes, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/images/kabhom/common/favicon.ico" rel="icon" type="image/ico"/>
# <link href="/css/kabhom/main/hom.css" rel="stylesheet" type="text/css"/>
# <link href="/css/kabhom/main/scrap/virtual.css" rel="stylesheet" type="text/css"/>
# <title>청약홈</title>
# <script src="/js/kabhom/plugin/jquery.3.1.1.min.js"></script>
# <script src="/js/kabhom/plugin/jquery-ui.min.js"></script>
# <script src="/js/kabhom/main/site.js"></script>
# <script>
# 		document.domain = "applyhome.co.kr";
# 	</script>
# </head>
# <body class="popBody" style="overflow:auto">
# <div id="printArea">
# <h5 class="sub_tit print_wrap"><b>입주자모집공고 주요정보</b></h5>
# <table class="tbl_st tbl_normal tbl_center">
# <caption class="blind">입주자모집공고 주요정보</caption>
# <colgroup>
# <col style="width:25%"/>
# <col style="width:auto"/>
# </colgroup>
# <thead>
# <tr>
# <th colspan="2" scope="col">남울산 노르웨이숲</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>공급위치  </td>
# <td class="txt_l">울산광역시 울주군 온양읍 발리 440-1번지 일원</td>
# </tr>
# <tr>
# <td>공급규모</td>
# <td class="txt_l">332세대</td>
# </tr>
# <tr>
# <td>입주자모집공고 관련 문의</td>
# <td class="txt_l">
# 				사업주체 또는 분양사무실로 문의
# 				</td>
# </tr>
# <tr>
# <td>문의처</td>
# <td class="txt_l">
# <a class="btn_org" href="tel:052-256-0300" style="padding:3px 7px">☎ 052-256-0300</a>
# </td>
# </tr>
# </tbody>
# </table>
# <dl class="pop_btn_txt mt_10">
# <dt></dt>
# <dd>
# <a class="radius_btn" href="https://static.applyhome.co.kr/ai/aia/getAtchmnfl.do?houseManageNo=2024000750&amp;pblancNo=2024000750&amp;atchmnflSeqNo=1450025&amp;atchmnflSn=3">모집공고문 보기</a>
# </dd>
# </dl>
# <h5 class="sub_sub_tit">청약일정</h5>
# <div class="">
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 청약일정</caption>
# <colgroup>
# <col style="width:20%"/>
# <col style="width:15%"/>
# <col style="width:25%"/>
# <col style="width:25%"/>
# <col style="width:15%"/>
# </colgroup>
# <tbody>
# <tr>
# <th scope="row">모집공고일</th>
# <td class="txt_l" colspan="4">2025-01-24 (내일신문)</td>
# </tr>
# <tr>
# <th rowspan="4" scope="row">청약접수</th>
# <td><b>구분</b></td>
# <td><b>해당지역</b></td>
# <td><b>기타지역</b></td>
# <td><b>접수장소</b></td>
# </tr>
# <tr>
# <td>특별공급</td>
# <td>2025-02-03</td>
# <td>2025-02-03</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <td>1순위</td>
# <td>2025-02-04</td>
# <td>2025-02-04</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <td>2순위</td>
# <td>2025-02-05</td>
# <td>2025-02-05</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <th rowspan="1" scope="row">당첨자 발표일</th>
# <td class="txt_l" colspan="4">2025-02-11
# 								 ( <a href="http://남울산노르웨이숲.com" target="_blank"><span style="color: #0e4eb2; position: relative;">http://남울산노르웨이숲.com</span></a>
#
# 								 )
# 							</td>
# </tr>
# <tr>
# <th rowspan="1" scope="row">계약일</th>
# <td class="txt_l" colspan="4">2025-02-24 ~ 2025-02-26</td>
# </tr>
# </tbody>
# </table>
# </div>
# <ul class="inde_txt">
# <li>* 특별공급 종류에 따라 접수기간 및 장소가 다를 수 있으니 모집공고를 반드시 확인하시기 바랍니다.</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">공급대상</h5>
# <div class="tbl_scroll">
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 공급대상</caption>
# <colgroup>
# <col style="width: 5%;"/>
# <col style="width: 11%;"/>
# <col style="width: 17%;"/>
# <col style="width:7%"/>
# <col style="width:7%"/>
# <col style="width:7%"/>
# <col style="width:auto"/>
# </colgroup>
# <thead>
# <tr>
# <th rowspan="2" scope="col">주택<br/>구분</th>
# <th rowspan="2" scope="col">주택형</th>
# <th rowspan="2" scope="col">주택공급면적<br>(주거전용+주거공용)</br></th>
# <th colspan="3" scope="colgroup">공급세대수</th>
# <th rowspan="2" scope="col">주택관리번호(모델번호)</th>
# </tr>
# <tr>
# <th scope="col">일반</th>
# <th scope="col">특별</th>
# <th scope="col">계</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td rowspan="6">민영</td>
# <td>059.9957A</td>
# <td>81.0764</td>
# <td>24</td>
# <td>35</td>
# <td>59</td>
# <td>2024000750(01)</td>
# </tr>
# <tr>
# <td>059.9734B</td>
# <td>81.7591</td>
# <td>32</td>
# <td>44</td>
# <td>76</td>
# <td>2024000750(02)</td>
# </tr>
# <tr>
# <td>074.5847A</td>
# <td>99.6395</td>
# <td>20</td>
# <td>29</td>
# <td>49</td>
# <td>2024000750(03)</td>
# </tr>
# <tr>
# <td>074.9026B</td>
# <td>100.9108</td>
# <td>19</td>
# <td>27</td>
# <td>46</td>
# <td>2024000750(04)</td>
# </tr>
# <tr>
# <td>084.9350A</td>
# <td>113.0813</td>
# <td>24</td>
# <td>35</td>
# <td>59</td>
# <td>2024000750(05)</td>
# </tr>
# <tr>
# <td>084.4955B</td>
# <td>113.0982</td>
# <td>18</td>
# <td>25</td>
# <td>43</td>
# <td>2024000750(06)</td>
# </tr>
# <tr>
# <td colspan="3">계</td>
# <td>137</td>
# <td>195</td>
# <td>332</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# </div>
# <h5 class="sub_sub_tit mt_30">특별공급 공급대상</h5>
# <div class="tbl_scroll">
# <p class="tbl_caption">단위 (세대)</p>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 특별공급 공급대상</caption>
# <colgroup>
# <col style="width:19%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# </colgroup>
# <thead>
# <tr>
# <th rowspan="2" scope="col">주택형</th>
# <th colspan="10" id="thHshldco" scope="colgroup">공급세대수</th>
# </tr>
# <tr id="trHshldco">
# <th scope="col">다자녀<br/>가구</th>
# <th scope="col">신혼부부</th>
# <th scope="col">생애최초</th>
# <th scope="col">청년</th>
# <th scope="col">노부모<br/>부양</th>
# <th scope="col">신생아<br/>(일반형)</th>
# <th scope="col">기관추천</th>
# <th scope="col">이전기관</th>
# <th scope="col">기타</th>
# <th scope="col">계</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>059.9957A</td>
# <td>9</td>
# <td>12</td>
# <td>6</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>6</td>
# <td>0</td>
# <td>0</td>
# <td>35</td>
# </tr>
# <tr>
# <td>059.9734B</td>
# <td>11</td>
# <td>15</td>
# <td>8</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>8</td>
# <td>0</td>
# <td>0</td>
# <td>44</td>
# </tr>
# <tr>
# <td>074.5847A</td>
# <td>7</td>
# <td>10</td>
# <td>5</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>5</td>
# <td>0</td>
# <td>0</td>
# <td>29</td>
# </tr>
# <tr>
# <td>074.9026B</td>
# <td>7</td>
# <td>9</td>
# <td>5</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>5</td>
# <td>0</td>
# <td>0</td>
# <td>27</td>
# </tr>
# <tr>
# <td>084.9350A</td>
# <td>9</td>
# <td>12</td>
# <td>6</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>6</td>
# <td>0</td>
# <td>0</td>
# <td>35</td>
# </tr>
# <tr>
# <td>084.4955B</td>
# <td>7</td>
# <td>9</td>
# <td>4</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>4</td>
# <td>0</td>
# <td>0</td>
# <td>25</td>
# </tr>
# </tbody>
# </table>
# </div>
# <ul class="inde_txt">
# <li>* 공급세대수는 사업주체의 최초 입주자모집 공고문 기준입니다. 특별공급 신청 미달 시 잔여물량은 일반공급으로 전환됨에따라 일반공급 세대 수가 변경될 수 있으므로 최종 일반공급 세대수는 일반공급 신청일에 '청약접수 경쟁률'에서 확인 또는 사업주체에 문의하시기 바랍니다.</li>
# <li>* 주택형=주거전용면적(type이 있는 경우 type포함)</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">공급금액, 2순위 청약금 및 입주예정월</h5>
# <p class="tbl_caption">공급금액(단위:만원)</p>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">공급금액, 2순위 청약금</caption>
# <colgroup>
# <col style="width:25%"/>
# <col style="width:20%"/>
# <col style="width:55%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">주택형</th>
# <th scope="col">공급금액(최고가 기준)</th>
# <th scope="col">2순위 청약금</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>059.9957A</td>
# <td class="txt_r">34,100</td>
# <td rowspan="6">청약통장으로 청약(청약금 없음)</td>
# </tr>
# <tr>
# <td>059.9734B</td>
# <td class="txt_r">33,700</td>
# </tr>
# <tr>
# <td>074.5847A</td>
# <td class="txt_r">41,800</td>
# </tr>
# <tr>
# <td>074.9026B</td>
# <td class="txt_r">41,100</td>
# </tr>
# <tr>
# <td>084.9350A</td>
# <td class="txt_r">48,900</td>
# </tr>
# <tr>
# <td>084.4955B</td>
# <td class="txt_r">47,500</td>
# </tr>
# </tbody>
# </table>
# <ul class="inde_txt">
# <li>* 입주예정월 : 2026.07</li>
# <li>* 층별(동호수별) 세부 공급금액은 사업주체의 입주자모집 공고문을 참고하시기 바랍니다.</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">기타사항</h5>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 기타사항</caption>
# <colgroup>
# <col style="width:38%"/>
# <col style="width:24%"/>
# <col style="width:38%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">시행사</th>
# <th scope="col">시공사</th>
# <th scope="col">사업주체 전화번호</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>울산온양발리스타지역주택조합</td>
# <td>(주)유림E&amp;C</td>
# <td style="padding:10px 5px">
# <a class="btn_org" href="tel:052-256-0300">052-256-0300</a>
# </td>
# </tr>
# </tbody>
# </table>
# <ul class="inde_txt">
# <li>* 시행사 및 시공사가 여러 업체인 경우 한 업체만 표시됩니다.</li>
# <!-- 		<br/> -->
# <li>* 기타 자세한 모집공고문 내용은 2025-01-24 (내일신문)에 게시된 내용을 참고하시기 바랍니다.</li>
# </ul>
# </div>
# <div class="btn_box">
# <button class="btn_cancel" type="button">닫기</button>
# <button class="btn_submit" id="btnPrint" type="button">인쇄하기</button>
# </div>
# <script>
# $(function() {
#
#
# 	$(".btn_box .btn_cancel").on('click', function() {
# 	 	$pop.closeDialog();
# 	});
#
#
# 	$('#btnPrint').on('click', function(){
# 		window.print();
# 	});
#
#
#
# });
# </script>
# <div id="divForPopup"></div>
# <script>
# 	var gvPgmId = "AIA01P02";
# </script>
# <script src="/js/kabhom/com/hom.core.js"></script>
# <script src="/js/kabhom/util/hom.all.js"></script>
# </body>
# </html>
# ((1, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000750&pblancNo=2024000750', '2024000750'), (2, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2025000004&pblancNo=2025000004', '2025000004'), (3, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2025000001&pblancNo=2025000001', '2025000001'), (4, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000747&pblancNo=2024000747', '2024000747'), (5, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000396&pblancNo=2024000396', '2024000396'), (6, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000725&pblancNo=2024000725', '2024000725'), (7, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000751&pblancNo=2024000751', '2024000751'), (8, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000742&pblancNo=2024000742', '2024000742'), (9, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024820019&pblancNo=2024820019', '2024820019'), (10, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000715&pblancNo=2024000715', '2024000715'), (11, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024820018&pblancNo=2024820018', '2024820018'), (12, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000661&pblancNo=2024000661', '2024000661'), (13, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000704&pblancNo=2024000704', '2024000704'), (14, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000726&pblancNo=2024000726', '2024000726'), (15, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000733&pblancNo=2024000733', '2024000733'), (16, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000732&pblancNo=2024000732', '2024000732'), (17, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000731&pblancNo=2024000731', '2024000731'), (18, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000730&pblancNo=2024000730', '2024000730'), (19, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000729&pblancNo=2024000729', '2024000729'), (20, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000727&pblancNo=2024000727', '2024000727'), (21, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000713&pblancNo=2024000713', '2024000713'), (22, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000706&pblancNo=2024000706', '2024000706'), (23, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000686&pblancNo=2024000686', '2024000686'), (24, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000221&pblancNo=2024000221', '2024000221'), (25, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000312&pblancNo=2024000312', '2024000312'), (26, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000723&pblancNo=2024000723', '2024000723'), (27, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000718&pblancNo=2024000718', '2024000718'), (28, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000712&pblancNo=2024000712', '2024000712'), (29, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000714&pblancNo=2024000714', '2024000714'), (30, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000698&pblancNo=2024000698', '2024000698'), (31, 'https://www. ...
# ID 2 공급대상 정보 삽입 완료: 5 건
# ID 2 특별공급 공급대상 정보 삽입 완료: 5 건
# ID 2 공급금액 정보 삽입 완료: 5 건
# <Response [200]>
#
# <!DOCTYPE html>
#
# <html lang="ko" style="overflow: hidden;height:97%">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, user-scalable=yes, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/images/kabhom/common/favicon.ico" rel="icon" type="image/ico"/>
# <link href="/css/kabhom/main/hom.css" rel="stylesheet" type="text/css"/>
# <link href="/css/kabhom/main/scrap/virtual.css" rel="stylesheet" type="text/css"/>
# <title>청약홈</title>
# <script src="/js/kabhom/plugin/jquery.3.1.1.min.js"></script>
# <script src="/js/kabhom/plugin/jquery-ui.min.js"></script>
# <script src="/js/kabhom/main/site.js"></script>
# <script>
# 		document.domain = "applyhome.co.kr";
# 	</script>
# </head>
# <body class="popBody" style="overflow:auto">
# <div id="printArea">
# <h5 class="sub_tit print_wrap"><b>입주자모집공고 주요정보</b></h5>
# <table class="tbl_st tbl_normal tbl_center">
# <caption class="blind">입주자모집공고 주요정보</caption>
# <colgroup>
# <col style="width:25%"/>
# <col style="width:auto"/>
# </colgroup>
# <thead>
# <tr>
# <th colspan="2" scope="col">양주 용암 영무 예다음 더퍼스트</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>공급위치  </td>
# <td class="txt_l">경기도 양주시 은현면 용암리 784-8번지 일원</td>
# </tr>
# <tr>
# <td>공급규모</td>
# <td class="txt_l">285세대</td>
# </tr>
# <tr>
# <td>입주자모집공고 관련 문의</td>
# <td class="txt_l">
# 				사업주체 또는 분양사무실로 문의
# 				</td>
# </tr>
# <tr>
# <td>문의처</td>
# <td class="txt_l">
# <a class="btn_org" href="tel:1877-2066" style="padding:3px 7px">☎ 1877-2066</a>
# </td>
# </tr>
# </tbody>
# </table>
# <dl class="pop_btn_txt mt_10">
# <dt></dt>
# <dd>
# <a class="radius_btn" href="https://static.applyhome.co.kr/ai/aia/getAtchmnfl.do?houseManageNo=2025000004&amp;pblancNo=2025000004&amp;atchmnflSeqNo=1442191&amp;atchmnflSn=3">모집공고문 보기</a>
# </dd>
# </dl>
# <h5 class="sub_sub_tit">청약일정</h5>
# <div class="">
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 청약일정</caption>
# <colgroup>
# <col style="width:20%"/>
# <col style="width:15%"/>
# <col style="width:25%"/>
# <col style="width:25%"/>
# <col style="width:15%"/>
# </colgroup>
# <tbody>
# <tr>
# <th scope="row">모집공고일</th>
# <td class="txt_l" colspan="4">2025-01-17 (아시아경제)</td>
# </tr>
# <tr>
# <th rowspan="4" scope="row">청약접수</th>
# <td><b>구분</b></td>
# <td><b>해당지역</b></td>
# <td><b>기타지역</b></td>
# <td><b>접수장소</b></td>
# </tr>
# <tr>
# <td>특별공급</td>
# <td>2025-01-31</td>
# <td>2025-01-31</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <td>1순위</td>
# <td>2025-02-03</td>
# <td>2025-02-03</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <td>2순위</td>
# <td>2025-02-04</td>
# <td>2025-02-04</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <th rowspan="1" scope="row">당첨자 발표일</th>
# <td class="txt_l" colspan="4">2025-02-10
# 								 ( <a href="http://www.양주영무예다음.com" target="_blank"><span style="color: #0e4eb2; position: relative;">http://www.양주영무예다음.com</span></a>
#
# 								 )
# 							</td>
# </tr>
# <tr>
# <th rowspan="1" scope="row">계약일</th>
# <td class="txt_l" colspan="4">2025-02-21 ~ 2025-02-23</td>
# </tr>
# </tbody>
# </table>
# </div>
# <ul class="inde_txt">
# <li>* 특별공급 종류에 따라 접수기간 및 장소가 다를 수 있으니 모집공고를 반드시 확인하시기 바랍니다.</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">공급대상</h5>
# <div class="tbl_scroll">
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 공급대상</caption>
# <colgroup>
# <col style="width: 5%;"/>
# <col style="width: 11%;"/>
# <col style="width: 17%;"/>
# <col style="width:7%"/>
# <col style="width:7%"/>
# <col style="width:7%"/>
# <col style="width:auto"/>
# </colgroup>
# <thead>
# <tr>
# <th rowspan="2" scope="col">주택<br/>구분</th>
# <th rowspan="2" scope="col">주택형</th>
# <th rowspan="2" scope="col">주택공급면적<br>(주거전용+주거공용)</br></th>
# <th colspan="3" scope="colgroup">공급세대수</th>
# <th rowspan="2" scope="col">주택관리번호(모델번호)</th>
# </tr>
# <tr>
# <th scope="col">일반</th>
# <th scope="col">특별</th>
# <th scope="col">계</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td rowspan="5">민영</td>
# <td>059.9973A</td>
# <td>81.1333</td>
# <td>80</td>
# <td>77</td>
# <td>157</td>
# <td>2025000004(01)</td>
# </tr>
# <tr>
# <td>059.9957B</td>
# <td>81.7355</td>
# <td>14</td>
# <td>9</td>
# <td>23</td>
# <td>2025000004(02)</td>
# </tr>
# <tr>
# <td>075.9281A</td>
# <td>99.0653</td>
# <td>36</td>
# <td>29</td>
# <td>65</td>
# <td>2025000004(03)</td>
# </tr>
# <tr>
# <td>084.6964A</td>
# <td>112.1192</td>
# <td>18</td>
# <td>12</td>
# <td>30</td>
# <td>2025000004(04)</td>
# </tr>
# <tr>
# <td>084.9963B</td>
# <td>111.9818</td>
# <td>5</td>
# <td>5</td>
# <td>10</td>
# <td>2025000004(05)</td>
# </tr>
# <tr>
# <td colspan="3">계</td>
# <td>153</td>
# <td>132</td>
# <td>285</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# </div>
# <h5 class="sub_sub_tit mt_30">특별공급 공급대상</h5>
# <div class="tbl_scroll">
# <p class="tbl_caption">단위 (세대)</p>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 특별공급 공급대상</caption>
# <colgroup>
# <col style="width:19%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# </colgroup>
# <thead>
# <tr>
# <th rowspan="2" scope="col">주택형</th>
# <th colspan="10" id="thHshldco" scope="colgroup">공급세대수</th>
# </tr>
# <tr id="trHshldco">
# <th scope="col">다자녀<br/>가구</th>
# <th scope="col">신혼부부</th>
# <th scope="col">생애최초</th>
# <th scope="col">청년</th>
# <th scope="col">노부모<br/>부양</th>
# <th scope="col">신생아<br/>(일반형)</th>
# <th scope="col">기관추천</th>
# <th scope="col">이전기관</th>
# <th scope="col">기타</th>
# <th scope="col">계</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>059.9973A</td>
# <td>15</td>
# <td>28</td>
# <td>15</td>
# <td>0</td>
# <td>4</td>
# <td>0</td>
# <td>15</td>
# <td>0</td>
# <td>0</td>
# <td>77</td>
# </tr>
# <tr>
# <td>059.9957B</td>
# <td>2</td>
# <td>3</td>
# <td>1</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>9</td>
# </tr>
# <tr>
# <td>075.9281A</td>
# <td>6</td>
# <td>11</td>
# <td>5</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>6</td>
# <td>0</td>
# <td>0</td>
# <td>29</td>
# </tr>
# <tr>
# <td>084.6964A</td>
# <td>2</td>
# <td>5</td>
# <td>2</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>12</td>
# </tr>
# <tr>
# <td>084.9963B</td>
# <td>1</td>
# <td>1</td>
# <td>1</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>5</td>
# </tr>
# </tbody>
# </table>
# </div>
# <ul class="inde_txt">
# <li>* 공급세대수는 사업주체의 최초 입주자모집 공고문 기준입니다. 특별공급 신청 미달 시 잔여물량은 일반공급으로 전환됨에따라 일반공급 세대 수가 변경될 수 있으므로 최종 일반공급 세대수는 일반공급 신청일에 '청약접수 경쟁률'에서 확인 또는 사업주체에 문의하시기 바랍니다.</li>
# <li>* 주택형=주거전용면적(type이 있는 경우 type포함)</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">공급금액, 2순위 청약금 및 입주예정월</h5>
# <p class="tbl_caption">공급금액(단위:만원)</p>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">공급금액, 2순위 청약금</caption>
# <colgroup>
# <col style="width:25%"/>
# <col style="width:20%"/>
# <col style="width:55%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">주택형</th>
# <th scope="col">공급금액(최고가 기준)</th>
# <th scope="col">2순위 청약금</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>059.9973A</td>
# <td class="txt_r">37,980</td>
# <td rowspan="5">청약통장으로 청약(청약금 없음)</td>
# </tr>
# <tr>
# <td>059.9957B</td>
# <td class="txt_r">38,240</td>
# </tr>
# <tr>
# <td>075.9281A</td>
# <td class="txt_r">46,070</td>
# </tr>
# <tr>
# <td>084.6964A</td>
# <td class="txt_r">51,980</td>
# </tr>
# <tr>
# <td>084.9963B</td>
# <td class="txt_r">51,920</td>
# </tr>
# </tbody>
# </table>
# <ul class="inde_txt">
# <li>* 입주예정월 : 2027.11</li>
# <li>* 층별(동호수별) 세부 공급금액은 사업주체의 입주자모집 공고문을 참고하시기 바랍니다.</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">기타사항</h5>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 기타사항</caption>
# <colgroup>
# <col style="width:38%"/>
# <col style="width:24%"/>
# <col style="width:38%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">시행사</th>
# <th scope="col">시공사</th>
# <th scope="col">사업주체 전화번호</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>양주용암3지구지역주택조합</td>
# <td>(주)영무토건</td>
# <td style="padding:10px 5px">
# <a class="btn_org" href="tel:1877-2066">1877-2066</a>
# </td>
# </tr>
# </tbody>
# </table>
# <ul class="inde_txt">
# <li>* 시행사 및 시공사가 여러 업체인 경우 한 업체만 표시됩니다.</li>
# <!-- 		<br/> -->
# <li>* 기타 자세한 모집공고문 내용은 2025-01-17 (아시아경제)에 게시된 내용을 참고하시기 바랍니다.</li>
# </ul>
# </div>
# <div class="btn_box">
# <button class="btn_cancel" type="button">닫기</button>
# <button class="btn_submit" id="btnPrint" type="button">인쇄하기</button>
# </div>
# <script>
# $(function() {
#
#
# 	$(".btn_box .btn_cancel").on('click', function() {
# 	 	$pop.closeDialog();
# 	});
#
#
# 	$('#btnPrint').on('click', function(){
# 		window.print();
# 	});
#
#
#
# });
# </script>
# <div id="divForPopup"></div>
# <script>
# 	var gvPgmId = "AIA01P02";
# </script>
# <script src="/js/kabhom/com/hom.core.js"></script>
# <script src="/js/kabhom/util/hom.all.js"></script>
# </body>
# </html>
# ((1, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000750&pblancNo=2024000750', '2024000750'), (2, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2025000004&pblancNo=2025000004', '2025000004'), (3, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2025000001&pblancNo=2025000001', '2025000001'), (4, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000747&pblancNo=2024000747', '2024000747'), (5, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000396&pblancNo=2024000396', '2024000396'), (6, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000725&pblancNo=2024000725', '2024000725'), (7, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000751&pblancNo=2024000751', '2024000751'), (8, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000742&pblancNo=2024000742', '2024000742'), (9, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024820019&pblancNo=2024820019', '2024820019'), (10, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000715&pblancNo=2024000715', '2024000715'), (11, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024820018&pblancNo=2024820018', '2024820018'), (12, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000661&pblancNo=2024000661', '2024000661'), (13, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000704&pblancNo=2024000704', '2024000704'), (14, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000726&pblancNo=2024000726', '2024000726'), (15, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000733&pblancNo=2024000733', '2024000733'), (16, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000732&pblancNo=2024000732', '2024000732'), (17, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000731&pblancNo=2024000731', '2024000731'), (18, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000730&pblancNo=2024000730', '2024000730'), (19, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000729&pblancNo=2024000729', '2024000729'), (20, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000727&pblancNo=2024000727', '2024000727'), (21, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000713&pblancNo=2024000713', '2024000713'), (22, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000706&pblancNo=2024000706', '2024000706'), (23, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000686&pblancNo=2024000686', '2024000686'), (24, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000221&pblancNo=2024000221', '2024000221'), (25, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000312&pblancNo=2024000312', '2024000312'), (26, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000723&pblancNo=2024000723', '2024000723'), (27, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000718&pblancNo=2024000718', '2024000718'), (28, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000712&pblancNo=2024000712', '2024000712'), (29, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000714&pblancNo=2024000714', '2024000714'), (30, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000698&pblancNo=2024000698', '2024000698'), (31, 'https://www. ...
# ID 3 공급대상 정보 삽입 완료: 11 건
# ID 3 특별공급 공급대상 정보 삽입 완료: 11 건
# ID 3 공급금액 정보 삽입 완료: 11 건
# <Response [200]>
#
# <!DOCTYPE html>
#
# <html lang="ko" style="overflow: hidden;height:97%">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, user-scalable=yes, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/images/kabhom/common/favicon.ico" rel="icon" type="image/ico"/>
# <link href="/css/kabhom/main/hom.css" rel="stylesheet" type="text/css"/>
# <link href="/css/kabhom/main/scrap/virtual.css" rel="stylesheet" type="text/css"/>
# <title>청약홈</title>
# <script src="/js/kabhom/plugin/jquery.3.1.1.min.js"></script>
# <script src="/js/kabhom/plugin/jquery-ui.min.js"></script>
# <script src="/js/kabhom/main/site.js"></script>
# <script>
# 		document.domain = "applyhome.co.kr";
# 	</script>
# </head>
# <body class="popBody" style="overflow:auto">
# <div id="printArea">
# <h5 class="sub_tit print_wrap"><b>입주자모집공고 주요정보</b></h5>
# <table class="tbl_st tbl_normal tbl_center">
# <caption class="blind">입주자모집공고 주요정보</caption>
# <colgroup>
# <col style="width:25%"/>
# <col style="width:auto"/>
# </colgroup>
# <thead>
# <tr>
# <th colspan="2" scope="col">래미안 원페를라</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>공급위치  </td>
# <td class="txt_l">서울특별시 서초구 방배동 818-14번지 일대</td>
# </tr>
# <tr>
# <td>공급규모</td>
# <td class="txt_l">482세대</td>
# </tr>
# <tr>
# <td>입주자모집공고 관련 문의</td>
# <td class="txt_l">
# 				사업주체 또는 분양사무실로 문의
# 				</td>
# </tr>
# <tr>
# <td>문의처</td>
# <td class="txt_l">
# <a class="btn_org" href="tel:02-407-1097" style="padding:3px 7px">☎ 02-407-1097</a>
# </td>
# </tr>
# </tbody>
# </table>
# <dl class="pop_btn_txt mt_10">
# <dt></dt>
# <dd>
# <a class="radius_btn" href="https://static.applyhome.co.kr/ai/aia/getAtchmnfl.do?houseManageNo=2025000001&amp;pblancNo=2025000001&amp;atchmnflSeqNo=1442154&amp;atchmnflSn=2">모집공고문 보기</a>
# </dd>
# </dl>
# <h5 class="sub_sub_tit">청약일정</h5>
# <div class="">
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 청약일정</caption>
# <colgroup>
# <col style="width:20%"/>
# <col style="width:15%"/>
# <col style="width:25%"/>
# <col style="width:25%"/>
# <col style="width:15%"/>
# </colgroup>
# <tbody>
# <tr>
# <th scope="row">모집공고일</th>
# <td class="txt_l" colspan="4">2025-01-17 (한국경제 )</td>
# </tr>
# <tr>
# <th rowspan="4" scope="row">청약접수</th>
# <td><b>구분</b></td>
# <td><b>해당지역</b></td>
# <td><b>기타지역</b></td>
# <td><b>접수장소</b></td>
# </tr>
# <tr>
# <td>특별공급</td>
# <td>2025-02-03</td>
# <td>2025-02-03</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <td>1순위</td>
# <td>2025-02-04</td>
# <td>2025-02-05</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <td>2순위</td>
# <td>2025-02-06</td>
# <td>2025-02-06</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <th rowspan="1" scope="row">당첨자 발표일</th>
# <td class="txt_l" colspan="4">2025-02-12
# 								 ( <a href="https://www.raemian.co.kr" target="_blank"><span style="color: #0e4eb2; position: relative;">https://www.raemian.co.kr</span></a>
#
# 								 )
# 							</td>
# </tr>
# <tr>
# <th rowspan="1" scope="row">계약일</th>
# <td class="txt_l" colspan="4">2025-02-24 ~ 2025-02-27</td>
# </tr>
# </tbody>
# </table>
# </div>
# <ul class="inde_txt">
# <li>* 특이사항 : 투기과열지구, 청약과열지역, 분양가상한제, 정비사업</li>
# <li>* 특별공급 종류에 따라 접수기간 및 장소가 다를 수 있으니 모집공고를 반드시 확인하시기 바랍니다.</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">공급대상</h5>
# <div class="tbl_scroll">
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 공급대상</caption>
# <colgroup>
# <col style="width: 5%;"/>
# <col style="width: 11%;"/>
# <col style="width: 17%;"/>
# <col style="width:7%"/>
# <col style="width:7%"/>
# <col style="width:7%"/>
# <col style="width:auto"/>
# </colgroup>
# <thead>
# <tr>
# <th rowspan="2" scope="col">주택<br/>구분</th>
# <th rowspan="2" scope="col">주택형</th>
# <th rowspan="2" scope="col">주택공급면적<br>(주거전용+주거공용)</br></th>
# <th colspan="3" scope="colgroup">공급세대수</th>
# <th rowspan="2" scope="col">주택관리번호(모델번호)</th>
# </tr>
# <tr>
# <th scope="col">일반</th>
# <th scope="col">특별</th>
# <th scope="col">계</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td rowspan="11">민영</td>
# <td>059.9800A</td>
# <td>81.0000</td>
# <td>35</td>
# <td>37</td>
# <td>72</td>
# <td>2025000001(01)</td>
# </tr>
# <tr>
# <td>059.9500B</td>
# <td>82.0500</td>
# <td>30</td>
# <td>29</td>
# <td>59</td>
# <td>2025000001(02)</td>
# </tr>
# <tr>
# <td>059.7800C</td>
# <td>81.2200</td>
# <td>14</td>
# <td>12</td>
# <td>26</td>
# <td>2025000001(03)</td>
# </tr>
# <tr>
# <td>084.7300A</td>
# <td>113.8100</td>
# <td>8</td>
# <td>8</td>
# <td>16</td>
# <td>2025000001(04)</td>
# </tr>
# <tr>
# <td>084.6800B</td>
# <td>113.3200</td>
# <td>82</td>
# <td>83</td>
# <td>165</td>
# <td>2025000001(05)</td>
# </tr>
# <tr>
# <td>084.9200C</td>
# <td>114.3000</td>
# <td>8</td>
# <td>7</td>
# <td>15</td>
# <td>2025000001(06)</td>
# </tr>
# <tr>
# <td>084.9700D</td>
# <td>113.9700</td>
# <td>18</td>
# <td>17</td>
# <td>35</td>
# <td>2025000001(07)</td>
# </tr>
# <tr>
# <td>084.9200E</td>
# <td>115.2100</td>
# <td>19</td>
# <td>15</td>
# <td>34</td>
# <td>2025000001(08)</td>
# </tr>
# <tr>
# <td>106.9700A</td>
# <td>142.0600</td>
# <td>8</td>
# <td>0</td>
# <td>8</td>
# <td>2025000001(09)</td>
# </tr>
# <tr>
# <td>106.8100B</td>
# <td>142.9300</td>
# <td>42</td>
# <td>6</td>
# <td>48</td>
# <td>2025000001(10)</td>
# </tr>
# <tr>
# <td>120.6300 </td>
# <td>160.6000</td>
# <td>4</td>
# <td>0</td>
# <td>4</td>
# <td>2025000001(11)</td>
# </tr>
# <tr>
# <td colspan="3">계</td>
# <td>268</td>
# <td>214</td>
# <td>482</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# </div>
# <h5 class="sub_sub_tit mt_30">특별공급 공급대상</h5>
# <div class="tbl_scroll">
# <p class="tbl_caption">단위 (세대)</p>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 특별공급 공급대상</caption>
# <colgroup>
# <col style="width:19%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# </colgroup>
# <thead>
# <tr>
# <th rowspan="2" scope="col">주택형</th>
# <th colspan="10" id="thHshldco" scope="colgroup">공급세대수</th>
# </tr>
# <tr id="trHshldco">
# <th scope="col">다자녀<br/>가구</th>
# <th scope="col">신혼부부</th>
# <th scope="col">생애최초</th>
# <th scope="col">청년</th>
# <th scope="col">노부모<br/>부양</th>
# <th scope="col">신생아<br/>(일반형)</th>
# <th scope="col">기관추천</th>
# <th scope="col">이전기관</th>
# <th scope="col">기타</th>
# <th scope="col">계</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>059.9800A</td>
# <td>8</td>
# <td>13</td>
# <td>7</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>7</td>
# <td>0</td>
# <td>0</td>
# <td>37</td>
# </tr>
# <tr>
# <td>059.9500B</td>
# <td>6</td>
# <td>10</td>
# <td>5</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>6</td>
# <td>0</td>
# <td>0</td>
# <td>29</td>
# </tr>
# <tr>
# <td>059.7800C</td>
# <td>2</td>
# <td>5</td>
# <td>2</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>12</td>
# </tr>
# <tr>
# <td>084.7300A</td>
# <td>2</td>
# <td>3</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>8</td>
# </tr>
# <tr>
# <td>084.6800B</td>
# <td>16</td>
# <td>30</td>
# <td>15</td>
# <td>0</td>
# <td>5</td>
# <td>0</td>
# <td>17</td>
# <td>0</td>
# <td>0</td>
# <td>83</td>
# </tr>
# <tr>
# <td>084.9200C</td>
# <td>2</td>
# <td>2</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>7</td>
# </tr>
# <tr>
# <td>084.9700D</td>
# <td>4</td>
# <td>6</td>
# <td>3</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>3</td>
# <td>0</td>
# <td>0</td>
# <td>17</td>
# </tr>
# <tr>
# <td>084.9200E</td>
# <td>2</td>
# <td>6</td>
# <td>3</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>3</td>
# <td>0</td>
# <td>0</td>
# <td>15</td>
# </tr>
# <tr>
# <td>106.9700A</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>106.8100B</td>
# <td>4</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>6</td>
# </tr>
# <tr>
# <td>120.6300 </td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# </tbody>
# </table>
# </div>
# <ul class="inde_txt">
# <li>* 공급세대수는 사업주체의 최초 입주자모집 공고문 기준입니다. 특별공급 신청 미달 시 잔여물량은 일반공급으로 전환됨에따라 일반공급 세대 수가 변경될 수 있으므로 최종 일반공급 세대수는 일반공급 신청일에 '청약접수 경쟁률'에서 확인 또는 사업주체에 문의하시기 바랍니다.</li>
# <li>* 주택형=주거전용면적(type이 있는 경우 type포함)</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">공급금액, 2순위 청약금 및 입주예정월</h5>
# <p class="tbl_caption">공급금액(단위:만원)</p>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">공급금액, 2순위 청약금</caption>
# <colgroup>
# <col style="width:25%"/>
# <col style="width:20%"/>
# <col style="width:55%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">주택형</th>
# <th scope="col">공급금액(최고가 기준)</th>
# <th scope="col">2순위 청약금</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>059.9800A</td>
# <td class="txt_r">172,470</td>
# <td rowspan="11">청약통장으로 청약(청약금 없음)</td>
# </tr>
# <tr>
# <td>059.9500B</td>
# <td class="txt_r">176,060</td>
# </tr>
# <tr>
# <td>059.7800C</td>
# <td class="txt_r">179,650</td>
# </tr>
# <tr>
# <td>084.7300A</td>
# <td class="txt_r">235,270</td>
# </tr>
# <tr>
# <td>084.6800B</td>
# <td class="txt_r">243,770</td>
# </tr>
# <tr>
# <td>084.9200C</td>
# <td class="txt_r">235,270</td>
# </tr>
# <tr>
# <td>084.9700D</td>
# <td class="txt_r">245,070</td>
# </tr>
# <tr>
# <td>084.9200E</td>
# <td class="txt_r">235,270</td>
# </tr>
# <tr>
# <td>106.9700A</td>
# <td class="txt_r">287,550</td>
# </tr>
# <tr>
# <td>106.8100B</td>
# <td class="txt_r">299,780</td>
# </tr>
# <tr>
# <td>120.6300 </td>
# <td class="txt_r">318,400</td>
# </tr>
# </tbody>
# </table>
# <ul class="inde_txt">
# <li>* 입주예정월 : 2025.11</li>
# <li>* 층별(동호수별) 세부 공급금액은 사업주체의 입주자모집 공고문을 참고하시기 바랍니다.</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">기타사항</h5>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 기타사항</caption>
# <colgroup>
# <col style="width:38%"/>
# <col style="width:24%"/>
# <col style="width:38%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">시행사</th>
# <th scope="col">시공사</th>
# <th scope="col">사업주체 전화번호</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>방배6구역주택재건축정비사업조합</td>
# <td>삼성물산(주)</td>
# <td style="padding:10px 5px">
# <a class="btn_org" href="tel:02-407-1097">02-407-1097</a>
# </td>
# </tr>
# </tbody>
# </table>
# <ul class="inde_txt">
# <li>* 시행사 및 시공사가 여러 업체인 경우 한 업체만 표시됩니다.</li>
# <!-- 		<br/> -->
# <li>* 기타 자세한 모집공고문 내용은 2025-01-17 (한국경제 )에 게시된 내용을 참고하시기 바랍니다.</li>
# </ul>
# </div>
# <div class="btn_box">
# <button class="btn_cancel" type="button">닫기</button>
# <button class="btn_submit" id="btnPrint" type="button">인쇄하기</button>
# </div>
# <script>
# $(function() {
#
#
# 	$(".btn_box .btn_cancel").on('click', function() {
# 	 	$pop.closeDialog();
# 	});
#
#
# 	$('#btnPrint').on('click', function(){
# 		window.print();
# 	});
#
#
#
# });
# </script>
# <div id="divForPopup"></div>
# <script>
# 	var gvPgmId = "AIA01P02";
# </script>
# <script src="/js/kabhom/com/hom.core.js"></script>
# <script src="/js/kabhom/util/hom.all.js"></script>
# </body>
# </html>
# ((1, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000750&pblancNo=2024000750', '2024000750'), (2, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2025000004&pblancNo=2025000004', '2025000004'), (3, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2025000001&pblancNo=2025000001', '2025000001'), (4, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000747&pblancNo=2024000747', '2024000747'), (5, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000396&pblancNo=2024000396', '2024000396'), (6, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000725&pblancNo=2024000725', '2024000725'), (7, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000751&pblancNo=2024000751', '2024000751'), (8, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000742&pblancNo=2024000742', '2024000742'), (9, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024820019&pblancNo=2024820019', '2024820019'), (10, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000715&pblancNo=2024000715', '2024000715'), (11, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024820018&pblancNo=2024820018', '2024820018'), (12, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000661&pblancNo=2024000661', '2024000661'), (13, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000704&pblancNo=2024000704', '2024000704'), (14, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000726&pblancNo=2024000726', '2024000726'), (15, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000733&pblancNo=2024000733', '2024000733'), (16, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000732&pblancNo=2024000732', '2024000732'), (17, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000731&pblancNo=2024000731', '2024000731'), (18, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000730&pblancNo=2024000730', '2024000730'), (19, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000729&pblancNo=2024000729', '2024000729'), (20, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000727&pblancNo=2024000727', '2024000727'), (21, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000713&pblancNo=2024000713', '2024000713'), (22, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000706&pblancNo=2024000706', '2024000706'), (23, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000686&pblancNo=2024000686', '2024000686'), (24, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000221&pblancNo=2024000221', '2024000221'), (25, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000312&pblancNo=2024000312', '2024000312'), (26, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000723&pblancNo=2024000723', '2024000723'), (27, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000718&pblancNo=2024000718', '2024000718'), (28, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000712&pblancNo=2024000712', '2024000712'), (29, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000714&pblancNo=2024000714', '2024000714'), (30, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000698&pblancNo=2024000698', '2024000698'), (31, 'https://www. ...
# ID 4 공급대상 정보 삽입 완료: 6 건
# ID 4 특별공급 공급대상 정보 삽입 완료: 6 건
# ID 4 공급금액 정보 삽입 완료: 6 건
# <Response [200]>
#
# <!DOCTYPE html>
#
# <html lang="ko" style="overflow: hidden;height:97%">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, user-scalable=yes, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/images/kabhom/common/favicon.ico" rel="icon" type="image/ico"/>
# <link href="/css/kabhom/main/hom.css" rel="stylesheet" type="text/css"/>
# <link href="/css/kabhom/main/scrap/virtual.css" rel="stylesheet" type="text/css"/>
# <title>청약홈</title>
# <script src="/js/kabhom/plugin/jquery.3.1.1.min.js"></script>
# <script src="/js/kabhom/plugin/jquery-ui.min.js"></script>
# <script src="/js/kabhom/main/site.js"></script>
# <script>
# 		document.domain = "applyhome.co.kr";
# 	</script>
# </head>
# <body class="popBody" style="overflow:auto">
# <div id="printArea">
# <h5 class="sub_tit print_wrap"><b>입주자모집공고 주요정보</b></h5>
# <table class="tbl_st tbl_normal tbl_center">
# <caption class="blind">입주자모집공고 주요정보</caption>
# <colgroup>
# <col style="width:25%"/>
# <col style="width:auto"/>
# </colgroup>
# <thead>
# <tr>
# <th colspan="2" scope="col">한양립스 에듀포레</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>공급위치  </td>
# <td class="txt_l">광주광역시 광산구 하산동 269번지 일원</td>
# </tr>
# <tr>
# <td>공급규모</td>
# <td class="txt_l">118세대</td>
# </tr>
# <tr>
# <td>입주자모집공고 관련 문의</td>
# <td class="txt_l">
# 				사업주체 또는 분양사무실로 문의
# 				</td>
# </tr>
# <tr>
# <td>문의처</td>
# <td class="txt_l">
# <a class="btn_org" href="tel:062-946-5552" style="padding:3px 7px">☎ 062-946-5552</a>
# </td>
# </tr>
# </tbody>
# </table>
# <dl class="pop_btn_txt mt_10">
# <dt></dt>
# <dd>
# <a class="radius_btn" href="https://static.applyhome.co.kr/ai/aia/getAtchmnfl.do?houseManageNo=2024000747&amp;pblancNo=2024000747&amp;atchmnflSeqNo=1442136&amp;atchmnflSn=2">모집공고문 보기</a>
# </dd>
# </dl>
# <h5 class="sub_sub_tit">청약일정</h5>
# <div class="">
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 청약일정</caption>
# <colgroup>
# <col style="width:20%"/>
# <col style="width:15%"/>
# <col style="width:25%"/>
# <col style="width:25%"/>
# <col style="width:15%"/>
# </colgroup>
# <tbody>
# <tr>
# <th scope="row">모집공고일</th>
# <td class="txt_l" colspan="4">2025-01-17 (광주매일)</td>
# </tr>
# <tr>
# <th rowspan="4" scope="row">청약접수</th>
# <td><b>구분</b></td>
# <td><b>해당지역</b></td>
# <td><b>기타지역</b></td>
# <td><b>접수장소</b></td>
# </tr>
# <tr>
# <td>특별공급</td>
# <td>2025-02-03</td>
# <td>2025-02-03</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <td>1순위</td>
# <td>2025-02-04</td>
# <td>2025-02-04</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <td>2순위</td>
# <td>2025-02-05</td>
# <td>2025-02-05</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <th rowspan="1" scope="row">당첨자 발표일</th>
# <td class="txt_l" colspan="4">2025-02-11
# 								 ( <a href="http://www.한양립스에듀포레.kr" target="_blank"><span style="color: #0e4eb2; position: relative;">http://www.한양립스에듀포레.kr</span></a>
#
# 								 )
# 							</td>
# </tr>
# <tr>
# <th rowspan="1" scope="row">계약일</th>
# <td class="txt_l" colspan="4">2025-02-24 ~ 2025-02-26</td>
# </tr>
# </tbody>
# </table>
# </div>
# <ul class="inde_txt">
# <li>* 특별공급 종류에 따라 접수기간 및 장소가 다를 수 있으니 모집공고를 반드시 확인하시기 바랍니다.</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">공급대상</h5>
# <div class="tbl_scroll">
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 공급대상</caption>
# <colgroup>
# <col style="width: 5%;"/>
# <col style="width: 11%;"/>
# <col style="width: 17%;"/>
# <col style="width:7%"/>
# <col style="width:7%"/>
# <col style="width:7%"/>
# <col style="width:auto"/>
# </colgroup>
# <thead>
# <tr>
# <th rowspan="2" scope="col">주택<br/>구분</th>
# <th rowspan="2" scope="col">주택형</th>
# <th rowspan="2" scope="col">주택공급면적<br>(주거전용+주거공용)</br></th>
# <th colspan="3" scope="colgroup">공급세대수</th>
# <th rowspan="2" scope="col">주택관리번호(모델번호)</th>
# </tr>
# <tr>
# <th scope="col">일반</th>
# <th scope="col">특별</th>
# <th scope="col">계</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td rowspan="6">민영</td>
# <td>084.9680A</td>
# <td>110.9204</td>
# <td>4</td>
# <td>0</td>
# <td>4</td>
# <td>2024000747(01)</td>
# </tr>
# <tr>
# <td>084.8642B</td>
# <td>109.7740</td>
# <td>11</td>
# <td>5</td>
# <td>16</td>
# <td>2024000747(02)</td>
# </tr>
# <tr>
# <td>084.9904C</td>
# <td>110.4641</td>
# <td>14</td>
# <td>8</td>
# <td>22</td>
# <td>2024000747(03)</td>
# </tr>
# <tr>
# <td>084.9636D</td>
# <td>110.0512</td>
# <td>6</td>
# <td>1</td>
# <td>7</td>
# <td>2024000747(04)</td>
# </tr>
# <tr>
# <td>089.5130A</td>
# <td>116.4234</td>
# <td>28</td>
# <td>3</td>
# <td>31</td>
# <td>2024000747(05)</td>
# </tr>
# <tr>
# <td>089.5204C</td>
# <td>115.9489</td>
# <td>34</td>
# <td>4</td>
# <td>38</td>
# <td>2024000747(06)</td>
# </tr>
# <tr>
# <td colspan="3">계</td>
# <td>97</td>
# <td>21</td>
# <td>118</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# </div>
# <h5 class="sub_sub_tit mt_30">특별공급 공급대상</h5>
# <div class="tbl_scroll">
# <p class="tbl_caption">단위 (세대)</p>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 특별공급 공급대상</caption>
# <colgroup>
# <col style="width:19%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# </colgroup>
# <thead>
# <tr>
# <th rowspan="2" scope="col">주택형</th>
# <th colspan="10" id="thHshldco" scope="colgroup">공급세대수</th>
# </tr>
# <tr id="trHshldco">
# <th scope="col">다자녀<br/>가구</th>
# <th scope="col">신혼부부</th>
# <th scope="col">생애최초</th>
# <th scope="col">청년</th>
# <th scope="col">노부모<br/>부양</th>
# <th scope="col">신생아<br/>(일반형)</th>
# <th scope="col">기관추천</th>
# <th scope="col">이전기관</th>
# <th scope="col">기타</th>
# <th scope="col">계</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>084.9680A</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>084.8642B</td>
# <td>1</td>
# <td>2</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>5</td>
# </tr>
# <tr>
# <td>084.9904C</td>
# <td>2</td>
# <td>3</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>8</td>
# </tr>
# <tr>
# <td>084.9636D</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# </tr>
# <tr>
# <td>089.5130A</td>
# <td>3</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>3</td>
# </tr>
# <tr>
# <td>089.5204C</td>
# <td>3</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>4</td>
# </tr>
# </tbody>
# </table>
# </div>
# <ul class="inde_txt">
# <li>* 공급세대수는 사업주체의 최초 입주자모집 공고문 기준입니다. 특별공급 신청 미달 시 잔여물량은 일반공급으로 전환됨에따라 일반공급 세대 수가 변경될 수 있으므로 최종 일반공급 세대수는 일반공급 신청일에 '청약접수 경쟁률'에서 확인 또는 사업주체에 문의하시기 바랍니다.</li>
# <li>* 주택형=주거전용면적(type이 있는 경우 type포함)</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">공급금액, 2순위 청약금 및 입주예정월</h5>
# <p class="tbl_caption">공급금액(단위:만원)</p>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">공급금액, 2순위 청약금</caption>
# <colgroup>
# <col style="width:25%"/>
# <col style="width:20%"/>
# <col style="width:55%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">주택형</th>
# <th scope="col">공급금액(최고가 기준)</th>
# <th scope="col">2순위 청약금</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>084.9680A</td>
# <td class="txt_r">56,200</td>
# <td rowspan="6">청약통장으로 청약(청약금 없음)</td>
# </tr>
# <tr>
# <td>084.8642B</td>
# <td class="txt_r">55,800</td>
# </tr>
# <tr>
# <td>084.9904C</td>
# <td class="txt_r">56,100</td>
# </tr>
# <tr>
# <td>084.9636D</td>
# <td class="txt_r">55,800</td>
# </tr>
# <tr>
# <td>089.5130A</td>
# <td class="txt_r">58,700</td>
# </tr>
# <tr>
# <td>089.5204C</td>
# <td class="txt_r">58,500</td>
# </tr>
# </tbody>
# </table>
# <ul class="inde_txt">
# <li>* 입주예정월 : 2027.11</li>
# <li>* 층별(동호수별) 세부 공급금액은 사업주체의 입주자모집 공고문을 참고하시기 바랍니다.</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">기타사항</h5>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 기타사항</caption>
# <colgroup>
# <col style="width:38%"/>
# <col style="width:24%"/>
# <col style="width:38%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">시행사</th>
# <th scope="col">시공사</th>
# <th scope="col">사업주체 전화번호</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>송정리버파크지역주택조합</td>
# <td>(주)한양건설</td>
# <td style="padding:10px 5px">
# <a class="btn_org" href="tel:062-946-5552">062-946-5552</a>
# </td>
# </tr>
# </tbody>
# </table>
# <ul class="inde_txt">
# <li>* 시행사 및 시공사가 여러 업체인 경우 한 업체만 표시됩니다.</li>
# <!-- 		<br/> -->
# <li>* 기타 자세한 모집공고문 내용은 2025-01-17 (광주매일)에 게시된 내용을 참고하시기 바랍니다.</li>
# </ul>
# </div>
# <div class="btn_box">
# <button class="btn_cancel" type="button">닫기</button>
# ...
# ID 50 공급대상 정보 삽입 완료: 5 건
# ID 50 특별공급 공급대상 정보 삽입 완료: 5 건
# ID 50 공급금액 정보 삽입 완료: 5 건
# <Response [200]>
#
# <!DOCTYPE html>
#
# <html lang="ko" style="overflow: hidden;height:97%">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, user-scalable=yes, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/images/kabhom/common/favicon.ico" rel="icon" type="image/ico"/>
# <link href="/css/kabhom/main/hom.css" rel="stylesheet" type="text/css"/>
# <link href="/css/kabhom/main/scrap/virtual.css" rel="stylesheet" type="text/css"/>
# <title>청약홈</title>
# <script src="/js/kabhom/plugin/jquery.3.1.1.min.js"></script>
# <script src="/js/kabhom/plugin/jquery-ui.min.js"></script>
# <script src="/js/kabhom/main/site.js"></script>
# <script>
# 		document.domain = "applyhome.co.kr";
# 	</script>
# </head>
# <body class="popBody" style="overflow:auto">
# <div id="printArea">
# <h5 class="sub_tit print_wrap"><b>입주자모집공고 주요정보</b></h5>
# <table class="tbl_st tbl_normal tbl_center">
# <caption class="blind">입주자모집공고 주요정보</caption>
# <colgroup>
# <col style="width:25%"/>
# <col style="width:auto"/>
# </colgroup>
# <thead>
# <tr>
# <th colspan="2" scope="col">더 플래티넘 스카이헤론</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>공급위치  </td>
# <td class="txt_l">경기도 평택시 통복동 108-3번지 일원</td>
# </tr>
# <tr>
# <td>공급규모</td>
# <td class="txt_l">784세대</td>
# </tr>
# <tr>
# <td>입주자모집공고 관련 문의</td>
# <td class="txt_l">
# 				사업주체 또는 분양사무실로 문의
# 				</td>
# </tr>
# <tr>
# <td>문의처</td>
# <td class="txt_l">
# <a class="btn_org" href="tel:031-655-1211" style="padding:3px 7px">☎ 031-655-1211</a>
# </td>
# </tr>
# </tbody>
# </table>
# <dl class="pop_btn_txt mt_10">
# <dt></dt>
# <dd>
# <a class="radius_btn" href="https://static.applyhome.co.kr/ai/aia/getAtchmnfl.do?houseManageNo=2024000619&amp;pblancNo=2024000619&amp;atchmnflSeqNo=1370234&amp;atchmnflSn=12">모집공고문 보기</a>
# </dd>
# </dl>
# <h5 class="sub_sub_tit">청약일정</h5>
# <div class="">
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 청약일정</caption>
# <colgroup>
# <col style="width:20%"/>
# <col style="width:15%"/>
# <col style="width:25%"/>
# <col style="width:25%"/>
# <col style="width:15%"/>
# </colgroup>
# <tbody>
# <tr>
# <th scope="row">모집공고일</th>
# <td class="txt_l" colspan="4">2024-11-15 (아시아경제)</td>
# </tr>
# <tr>
# <th rowspan="4" scope="row">청약접수</th>
# <td><b>구분</b></td>
# <td><b>해당지역</b></td>
# <td><b>기타지역</b></td>
# <td><b>접수장소</b></td>
# </tr>
# <tr>
# <td>특별공급</td>
# <td>2024-11-25</td>
# <td>2024-11-25</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <td>1순위</td>
# <td>2024-11-26</td>
# <td>2024-11-26</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <td>2순위</td>
# <td>2024-11-27</td>
# <td>2024-11-27</td>
# <td>인터넷</td>
# </tr>
# <tr>
# <th rowspan="1" scope="row">당첨자 발표일</th>
# <td class="txt_l" colspan="4">2024-12-04
# 								 ( <a href="http://더플래티넘스카이헤론.com" target="_blank"><span style="color: #0e4eb2; position: relative;">http://더플래티넘스카이헤론.com</span></a>
#
# 								 )
# 							</td>
# </tr>
# <tr>
# <th rowspan="1" scope="row">계약일</th>
# <td class="txt_l" colspan="4">2024-12-16 ~ 2024-12-18</td>
# </tr>
# </tbody>
# </table>
# </div>
# <ul class="inde_txt">
# <li>* 특별공급 종류에 따라 접수기간 및 장소가 다를 수 있으니 모집공고를 반드시 확인하시기 바랍니다.</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">공급대상</h5>
# <div class="tbl_scroll">
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 공급대상</caption>
# <colgroup>
# <col style="width: 5%;"/>
# <col style="width: 11%;"/>
# <col style="width: 17%;"/>
# <col style="width:7%"/>
# <col style="width:7%"/>
# <col style="width:7%"/>
# <col style="width:auto"/>
# </colgroup>
# <thead>
# <tr>
# <th rowspan="2" scope="col">주택<br/>구분</th>
# <th rowspan="2" scope="col">주택형</th>
# <th rowspan="2" scope="col">주택공급면적<br>(주거전용+주거공용)</br></th>
# <th colspan="3" scope="colgroup">공급세대수</th>
# <th rowspan="2" scope="col">주택관리번호(모델번호)</th>
# </tr>
# <tr>
# <th scope="col">일반</th>
# <th scope="col">특별</th>
# <th scope="col">계</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td rowspan="5">민영</td>
# <td>084.2100A</td>
# <td>113.9107</td>
# <td>249</td>
# <td>234</td>
# <td>483</td>
# <td>2024000619(01)</td>
# </tr>
# <tr>
# <td>084.8800B</td>
# <td>115.3883</td>
# <td>4</td>
# <td>10</td>
# <td>14</td>
# <td>2024000619(02)</td>
# </tr>
# <tr>
# <td>084.0600C</td>
# <td>115.3807</td>
# <td>4</td>
# <td>10</td>
# <td>14</td>
# <td>2024000619(03)</td>
# </tr>
# <tr>
# <td>110.9800 </td>
# <td>149.7857</td>
# <td>234</td>
# <td>36</td>
# <td>270</td>
# <td>2024000619(04)</td>
# </tr>
# <tr>
# <td>134.2700P</td>
# <td>185.2623</td>
# <td>1</td>
# <td>2</td>
# <td>3</td>
# <td>2024000619(05)</td>
# </tr>
# <tr>
# <td colspan="3">계</td>
# <td>492</td>
# <td>292</td>
# <td>784</td>
# <td></td>
# </tr>
# </tbody>
# </table>
# </div>
# <h5 class="sub_sub_tit mt_30">특별공급 공급대상</h5>
# <div class="tbl_scroll">
# <p class="tbl_caption">단위 (세대)</p>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 특별공급 공급대상</caption>
# <colgroup>
# <col style="width:19%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# <col style="width:8%"/>
# </colgroup>
# <thead>
# <tr>
# <th rowspan="2" scope="col">주택형</th>
# <th colspan="10" id="thHshldco" scope="colgroup">공급세대수</th>
# </tr>
# <tr id="trHshldco">
# <th scope="col">다자녀<br/>가구</th>
# <th scope="col">신혼부부</th>
# <th scope="col">생애최초</th>
# <th scope="col">청년</th>
# <th scope="col">노부모<br/>부양</th>
# <th scope="col">신생아<br/>(일반형)</th>
# <th scope="col">기관추천</th>
# <th scope="col">이전기관</th>
# <th scope="col">기타</th>
# <th scope="col">계</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>084.2100A</td>
# <td>46</td>
# <td>85</td>
# <td>42</td>
# <td>0</td>
# <td>13</td>
# <td>0</td>
# <td>48</td>
# <td>0</td>
# <td>0</td>
# <td>234</td>
# </tr>
# <tr>
# <td>084.8800B</td>
# <td>2</td>
# <td>3</td>
# <td>2</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>10</td>
# </tr>
# <tr>
# <td>084.0600C</td>
# <td>2</td>
# <td>3</td>
# <td>2</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>10</td>
# </tr>
# <tr>
# <td>110.9800 </td>
# <td>27</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>9</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>36</td>
# </tr>
# <tr>
# <td>134.2700P</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>2</td>
# </tr>
# </tbody>
# </table>
# </div>
# <ul class="inde_txt">
# <li>* 공급세대수는 사업주체의 최초 입주자모집 공고문 기준입니다. 특별공급 신청 미달 시 잔여물량은 일반공급으로 전환됨에따라 일반공급 세대 수가 변경될 수 있으므로 최종 일반공급 세대수는 일반공급 신청일에 '청약접수 경쟁률'에서 확인 또는 사업주체에 문의하시기 바랍니다.</li>
# <li>* 주택형=주거전용면적(type이 있는 경우 type포함)</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">공급금액, 2순위 청약금 및 입주예정월</h5>
# <p class="tbl_caption">공급금액(단위:만원)</p>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">공급금액, 2순위 청약금</caption>
# <colgroup>
# <col style="width:25%"/>
# <col style="width:20%"/>
# <col style="width:55%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">주택형</th>
# <th scope="col">공급금액(최고가 기준)</th>
# <th scope="col">2순위 청약금</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>084.2100A</td>
# <td class="txt_r">62,860</td>
# <td rowspan="5">청약통장으로 청약(청약금 없음)</td>
# </tr>
# <tr>
# <td>084.8800B</td>
# <td class="txt_r">61,700</td>
# </tr>
# <tr>
# <td>084.0600C</td>
# <td class="txt_r">58,610</td>
# </tr>
# <tr>
# <td>110.9800 </td>
# <td class="txt_r">99,870</td>
# </tr>
# <tr>
# <td>134.2700P</td>
# <td class="txt_r">185,230</td>
# </tr>
# </tbody>
# </table>
# <ul class="inde_txt">
# <li>* 입주예정월 : 2028.06</li>
# <li>* 층별(동호수별) 세부 공급금액은 사업주체의 입주자모집 공고문을 참고하시기 바랍니다.</li>
# </ul>
# <h5 class="sub_sub_tit mt_30">기타사항</h5>
# <table class="tbl_st tbl_row tbl_col tbl_center">
# <caption class="blind">입주자모집공고 기타사항</caption>
# <colgroup>
# <col style="width:38%"/>
# <col style="width:24%"/>
# <col style="width:38%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">시행사</th>
# <th scope="col">시공사</th>
# <th scope="col">사업주체 전화번호</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>교보자산신탁(주)</td>
# <td>쌍용건설(주)</td>
# <td style="padding:10px 5px">
# <a class="btn_org" href="tel:031-655-1211">031-655-1211</a>
# </td>
# </tr>
# </tbody>
# </table>
# <ul class="inde_txt">
# <li>* 시행사 및 시공사가 여러 업체인 경우 한 업체만 표시됩니다.</li>
# <!-- 		<br/> -->
# <li>* 기타 자세한 모집공고문 내용은 2024-11-15 (아시아경제)에 게시된 내용을 참고하시기 바랍니다.</li>
# </ul>
# </div>
# <div class="btn_box">
# <button class="btn_cancel" type="button">닫기</button>
# <button class="btn_submit" id="btnPrint" type="button">인쇄하기</button>
# </div>
# <script>
# $(function() {
#
#
# 	$(".btn_box .btn_cancel").on('click', function() {
# 	 	$pop.closeDialog();
# 	});
#
#
# 	$('#btnPrint').on('click', function(){
# 		window.print();
# 	});
#
#
#
# });
# </script>
# <div id="divForPopup"></div>
# <script>
# 	var gvPgmId = "AIA01P02";
# </script>
# <script src="/js/kabhom/com/hom.core.js"></script>
# <script src="/js/kabhom/util/hom.all.js"></script>
# </body>
# </html>
# ((1, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000750&pblancNo=2024000750', '2024000750'), (2, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2025000004&pblancNo=2025000004', '2025000004'), (3, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2025000001&pblancNo=2025000001', '2025000001'), (4, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000747&pblancNo=2024000747', '2024000747'), (5, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000396&pblancNo=2024000396', '2024000396'), (6, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000725&pblancNo=2024000725', '2024000725'), (7, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000751&pblancNo=2024000751', '2024000751'), (8, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000742&pblancNo=2024000742', '2024000742'), (9, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024820019&pblancNo=2024820019', '2024820019'), (10, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000715&pblancNo=2024000715', '2024000715'), (11, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024820018&pblancNo=2024820018', '2024820018'), (12, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000661&pblancNo=2024000661', '2024000661'), (13, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000704&pblancNo=2024000704', '2024000704'), (14, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000726&pblancNo=2024000726', '2024000726'), (15, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000733&pblancNo=2024000733', '2024000733'), (16, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000732&pblancNo=2024000732', '2024000732'), (17, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000731&pblancNo=2024000731', '2024000731'), (18, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000730&pblancNo=2024000730', '2024000730'), (19, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000729&pblancNo=2024000729', '2024000729'), (20, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000727&pblancNo=2024000727', '2024000727'), (21, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000713&pblancNo=2024000713', '2024000713'), (22, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000706&pblancNo=2024000706', '2024000706'), (23, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000686&pblancNo=2024000686', '2024000686'), (24, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000221&pblancNo=2024000221', '2024000221'), (25, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000312&pblancNo=2024000312', '2024000312'), (26, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000723&pblancNo=2024000723', '2024000723'), (27, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000718&pblancNo=2024000718', '2024000718'), (28, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000712&pblancNo=2024000712', '2024000712'), (29, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000714&pblancNo=2024000714', '2024000714'), (30, 'https://www.applyhome.co.kr/ai/aia/selectAPTLttotPblancDetail.do?houseManageNo=2024000698&pblancNo=2024000698', '2024000698'), (31, 'https://www. ...
